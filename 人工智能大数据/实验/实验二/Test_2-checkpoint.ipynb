# %%
## 实例一
import math
def fun(a,b,c):
    p =0.5 * (a+b+c)
    s =math.sqrt(p *(p-a) *(p-c) *(p-b))
    return s
while 1:#保持运行
    ans = input("是否要计算三角形的面积（yes/no）")#判断是否要计算面积
    if ans == 'yes':
        a =float(input('a = '))
        while a<=0:#边长值应大于0
            print("请输入大于0的值")
            a=float(input('a ='))
        b =float(input('b = '))
        while b<=0:
            print("请输入大于0的值")
            b =float(input('b ='))
        c =float(input('c = '))
        while c<=0:
            print("请输入大于0的值")
            c =float(input('c ='))
        if((a+b>c)and(a+c>b)and(b+c>a)):#判断是否符合三角形的组成条件
            s =fun(a,b,c)
            print("三角形的面积为：%.2f" % s)
        else:
            print("你所输入的三边长不能构成三角形")
    if ans == 'no':
        print("程序结束")
        break#不计算三角形面积，跳出循环
# Out:
# 是否要计算三角形的面积（yes/no）yes
# a = 3
# b = 3
# c = 3
# 三角形的面积为：3.90
# 是否要计算三角形的面积（yes/no）yes
# a = -1
# 请输入大于0的值
# a =3
# b = -1
# 请输入大于0的值
# b =3
# c = -1
# 请输入大于0的值
# c =3
# 三角形的面积为：3.90
# 是否要计算三角形的面积（yes/no）no
# 程序结束

# %%
## 实例二
import random#导入随机数模块
num =int(input("请输入班级人数："))
count=int(input("请输入点名人数："))
x=[]
while num < count:
    print('点名人数应小于等于班级人数，请重新输入：')
    num =int(input("请输入班级人数："))
    count =int(input("请输入点名人数："))
if num>= count:#点名人数应小于等于班级人数
    for i in range(0,count):
        x.append(random.randint(0,num))#生成一个从0到num（包括num）
        x=set(x)#利用set函数去重
        x=list(x)#转回列表
        while len(x)<i+1:
            x.append(random.randint(0,num))
            x=set(x)
            x=list(x)
    print(x)
# Out:
# 请输入班级人数：34
# 请输入点名人数：5
# [7, 13, 25, 27, 30]

# %%
## 实例三
money=float(input("请输入当月利润，单位为万元："))#接受利润值
bonus=0
li =[100,60,40,20,10,0]
bi =[0.01,0.015,0.03,0.05,0.075,0.1]
for i in range(6):
    if money >li[i]:
        cmoney =money-li[i]
        bonus = bonus +cmoney * bi[i]
        money = li[i]
print("当月应发放奖金总数为%s万元" %bonus)
# Out:
# 请输入当月利润，单位为万元：123
# 当月应发放奖金总数为4.18万元

# %%
## 实例四
for i in range(1,101):#在1-100之间
    if i % 7== 0 or i % 10 == 7 or int(i /10) == 7:#能被整除 个位 十位含有7
         print('*',end = ' ')
    else:
         print(i,end =' ')
# Out:
# 1 2 3 4 5 6 * 8 9 10 11 12 13 * 15 16 * 18 19 20 * 22 23 24 25 26 * * 29 30 31 32 33 34 * 36 * 38 39 40 41 * 43 44 45 46 * 48 * 50 51 52 53 54 55 * * 58 59 60 61 62 * 64 65 66 * 68 69 * * * * * * * * * * 80 81 82 83 * 85 86 * 88 89 90 * 92 93 94 95 96 * * 99 100

# %%
## 实例五
import random#引入随机数模块
ans =random.randint(0,100)#随机生成1-100以内的数字
count=0#记录游戏次数
for i in range(0,5):
    count += 1
    num =int(input("猜数字游戏，输入一个1-100以内的数字："))
    if num <ans:
        print("很遗憾，你猜小了")
    elif num >ans:
        print("很遗憾，你猜大了")
    elif num == ans:
        print("恭喜，你猜对了！")
        print("游戏结束，再见！^_^")
        break
    while count == 5 and num != ans:
        print("很遗憾，5次机会已用尽，游戏结束，答案为",ans)
        break
# Out:
# 猜数字游戏，输入一个1-100以内的数字：50
# 很遗憾，你猜大了
# 猜数字游戏，输入一个1-100以内的数字：25
# 很遗憾，你猜大了
# 猜数字游戏，输入一个1-100以内的数字：15
# 很遗憾，你猜小了
# 猜数字游戏，输入一个1-100以内的数字：20
# 很遗憾，你猜大了
# 猜数字游戏，输入一个1-100以内的数字：18
# 很遗憾，你猜大了
# 很遗憾，5次机会已用尽，游戏结束，答案为 17

# %%
## 实例六
import openpyxl
from student_510 import *
wb=openpyxl.Workbook()
wb.create_sheet(title='student')
ws=wb.active
ws['A1'] = '学号'
ws['B1'] = '姓名'
data_excel =[]#将字典中的每对数据(键，值)以列表形式传入data_excel列表
for each in dict_stu:
    data_excel.append([each,dict_stu[each]])#将data_excel列表内的内容存入工作表
for each in data_excel:
    ws.append(each)
wb.save('student_510.xlsx')
print('写入数据完毕')
# Out:
# 写入数据完毕

# %%
## 思考二
# 创建诗歌类
class Poem:
    def __init__(self,file_path,choice):
        self.file_path=file_path        # 路径实例
        self.choice=choice              # 方式示例
        self.lines=[]                   # 创建实例空列表

    # 导入诗歌
    def LoadPoetry(self):
        print('请输入诗歌每一行用空格隔开')
        self.L = input().split()
        for i in range(len(self.L)):
            self.L[i] = self.L[i] + '\n'  # 加入换行符 便于写入文件有好观感

    # 写入诗歌
    def WritePoetry(self):
        try:
            with open(file_path, 'w') as file:
                file.writelines(self.L)  # 以writelines 方式写入
        except Exception as e:
            print(f"An Unexpected Error Occurred:{e}")

    # 读取方式 权限：私有
    # file.read() 读取
    def __ReadPoetry1(self):
        try:
            with open(self.file_path, 'r') as file:
                lines1 = file.read()  # 整体读出 lines1 是一个字符串
            self.lines = lines1.split('\n')  # 以换行符进行字符串切割
        except FileNotFoundError:
            print('Error: The File Does Not Exist!')
        except PermissionError:
            print('Error: You Do Not Have Permisiion To Read The File!')
        except Exception as e:
            print(f"An Unexpected Error Occurred:{e}")

    # file.readlines() 读取
    def __ReadPoetry2(self):
        try:
            with open(self.file_path, 'r') as file:
                self.lines = file.readlines()  # 整体读出 linse2 是一个列表 元素是字符串
        except FileNotFoundError:
            print('Error: The File Does Not Exist!')
        except PermissionError:
            print('Error: You Do Not Have Permisiion To Read The File!')
        except Exception as e:
            print(f"An Unexpected Error Occurred:{e}")

    # file.readline() 读取
    def __ReadPoetry3(self):
        try:
            with open(self.file_path, 'r') as file:
                line = file.readline()
                self.lines.append(line)  # 将读出的字符串添加到列表
                while line != '':
                    line = file.readline()
                    if line != '':  # 避免列表后面会添加空字符串
                        self.lines.append(line)
        except FileNotFoundError:
            print('Error: The File Does Not Exist!')
        except PermissionError:
            print('Error: You Do Not Have Permisiion To Read The File!')
        except Exception as e:
            print(f"An Unexpected Error Occurred:{e}")

    # for循环 读取
    def __ReadPoetry4(self):
        try:
            with open(self.file_path, 'r') as file:
                for line in file:
                    self.lines.append(line)
        except FileNotFoundError:
            print('Error: The File Does Not Exist!')
        except PermissionError:
            print('Error: You Do Not Have Permisiion To Read The File!')
        except Exception as e:
            print(f"An Unexpected Error Occurred:{e}")

    # 读取方式选择函数
    def Switch(self):
        if self.choice == 1:
            print('-----------read 读取-----------')
            self.__ReadPoetry1()
        elif self.choice == 2:
            print('-----------readlines 读取-----------')
            self.__ReadPoetry2()
        elif self.choice == 3:
            print('-----------readline 读取-----------')
            self.__ReadPoetry3()
        elif self.choice == 4:
            print('-----------for循环 读取-----------')
            self.__ReadPoetry4()
        else:
            print('ERROR')
    #诗歌输出
    def PrintPoetry(self):
        cnt = 0
        w = max(map(len, self.lines)) + 3  # 获取填充长度
        print('\n-----------诗歌朗诵-----------')
        for item in self.lines:
            if cnt <= 1:
                print(item.strip().center(w))
            else:
                print(item.strip())
            cnt += 1
        print('\n-----------首句朗诵-----------')
        print(self.lines[2].strip())

# 主函数
if __name__ == "__main__":
    # 文件拓展名输入
    print('请输入正确学号 姓名 题号')
    ID,Name,Num=(input().split())
    file_path=f"{ID}-{Name}-{Num}.txt"
    # 选择读取方式
    print('请选择读取诗歌方式：1~4')
    choice = int(input())
    while choice>=5 or choice<=0:
        print('读取方式选择有误，请重新选择1~4')
        choice=int(input())
    # 调用实例函数
    Poetry=Poem(file_path,choice)
    Poetry.LoadPoetry()
    Poetry.WritePoetry()
    Poetry.Switch()
    Poetry.PrintPoetry()
# Out:
# 请输入正确学号 姓名 题号
